# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('D:\\projects\\DS_Pilot\\Задача от finstar\\sample test.xlsx')

# %%
encoded = pd.get_dummies(df)
encoded.head()
# Out:
#    fpd_5  account_last_week  age  gender  mobile_phone_prefix  \
# 0      0                  0   34       2                  905
# 1      0                  0   42       2                  932
# 2      0                  0   22       2                  917
# 3      0                  0   50       2                  906
# 4      0                  0   31       2                  916
#
#    year_month_2018-10  year_month_2018-11  year_month_2018-12  \
# 0                   1                   0                   0
# 1                   1                   0                   0
# 2                   1                   0                   0
# 3                   1                   0                   0
# 4                   1                   0                   0
#
#    year_month_2019-01  social_status_word_BPO Professionals  ...  \
# 0                   0                                     0  ...
# 1                   0                                     0  ...
# ...
